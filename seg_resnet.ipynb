# %%
"""
Input: segmented images
Output: labels (classes)

modification:
1. transform
2. input - DataLoader() to get seg images
3. output - classes
"""
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

import my_dataset_1


cudnn.benchmark = True
plt.ion()   # interactive mode
# Out:
# Using cache found in /home/t/tianqi/.cache/torch/hub/ultralytics_yolov5_master
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [5], line 25
#      22 import os
#      23 import copy
# ---> 25 import my_dataset_1
#      28 cudnn.benchmark = True
#      29 plt.ion()
#
# File ~/CS4243_proj/nn_merge/my_dataset_1.py:13
#      10 parent = os.path.dirname(current)
#      11 sys.path.append(parent)
# ---> 13 from utils.my_image import MyImage
#      14 import utils.seg as seg
#      15 import utils.get_pose as pose
#
# File ~/CS4243_proj/utils/my_image.py:7
#       5 import seg
#       6 import get_pose as pose
# ----> 7 import get_yolov5 as weapon
#       9 class_dict = {
#      10     "carrying": 0,
#      11     "normal": 1,
#      12     "threat": 2
#      13 }
#      15 class MyImage:
#
# File ~/CS4243_proj/utils/get_yolov5.py:3
#       1 import torch
# ----> 3 model = torch.hub.load('ultralytics/yolov5', 'custom', path='/home/t/tianqi/CS4243_proj/utils/best_11_09.pt')
#       4 model.conf = 0.1
#       6 def get_classification(file_path):
#
# File ~/.local/lib/python3.8/site-packages/torch/hub.py:540, in load(repo_or_dir, model, source, trust_repo, force_reload, verbose, skip_validation, *args, **kwargs)
#     536 if source == 'github':
#     537     repo_or_dir = _get_cache_or_reload(repo_or_dir, force_reload, trust_repo, "load",
#     538                                        verbose=verbose, skip_validation=skip_validation)
# --> 540 model = _load_local(repo_or_dir, model, *args, **kwargs)
#     541 return model
#
# File ~/.local/lib/python3.8/site-packages/torch/hub.py:569, in _load_local(hubconf_dir, model, *args, **kwargs)
#     566 hub_module = _import_module(MODULE_HUBCONF, hubconf_path)
#     568 entry = _load_entry_from_hubconf(hub_module, model)
# --> 569 model = entry(*args, **kwargs)
#     571 sys.path.remove(hubconf_dir)
#     573 return model
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py:83, in custom(path, autoshape, _verbose, device)
#      81 def custom(path='path/to/model.pt', autoshape=True, _verbose=True, device=None):
#      82     # YOLOv5 custom or local model
# ---> 83     return _create(path, autoshape=autoshape, verbose=_verbose, device=device)
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/hubconf.py:33, in _create(name, pretrained, channels, classes, autoshape, verbose, device)
#      17 """Creates or loads a YOLOv5 model
#      18
#      19 Arguments:
#    (...)
#      29     YOLOv5 model
#      30 """
#      31 from pathlib import Path
# ---> 33 from models.common import AutoShape, DetectMultiBackend
#      34 from models.experimental import attempt_load
#      35 from models.yolo import ClassificationModel, DetectionModel, SegmentationModel
#
# File ~/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:28
#      25 from PIL import Image
#      26 from torch.cuda import amp
# ---> 28 from utils import TryExcept
#      29 from utils.dataloaders import exif_transpose, letterbox
#      30 from utils.general import (LOGGER, ROOT, Profile, check_requirements, check_suffix, check_version, colorstr,
#      31                            increment_path, is_notebook, make_divisible, non_max_suppression, scale_boxes, xywh2xyxy,
#      32                            xyxy2xywh, yaml_load)
#
# ImportError: cannot import name 'TryExcept' from 'utils' (unknown location)

# %%
"""
transform: resize; nomralization
"""
data_transforms = transforms.Compose([
    transforms.Resize((640,640)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((.5,.5,.5),(.5,.5,.5))
])

data_dir = 'data'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms)
                  for x in ['train', 'val', 'test']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=4,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val', 'test']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
torch.cuda.get_device_properties(torch.device)
# Out:
# _CudaDeviceProperties(name='NVIDIA GeForce RTX 3060 Ti', major=8, minor=6, total_memory=8191MB, multi_processor_count=38)

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val', 'test']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %%
model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.fc = nn.Linear(num_ftrs, 3)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# train Loss: 1.1217 Acc: 0.4691
# val Loss: 1.0362 Acc: 0.5197
# test Loss: 1.0918 Acc: 0.4895
#
# Epoch 1/24
# ----------
# train Loss: 0.8593 Acc: 0.6192
# val Loss: 0.7230 Acc: 0.7060
# test Loss: 0.7827 Acc: 0.6526
#
# Epoch 2/24
# ----------
# train Loss: 0.6879 Acc: 0.7278
# val Loss: 0.9365 Acc: 0.6247
# test Loss: 0.8329 Acc: 0.6526
#
# Epoch 3/24
# ----------
# train Loss: 0.5869 Acc: 0.7647
# val Loss: 0.6208 Acc: 0.7822
# test Loss: 0.5200 Acc: 0.7842
#
# Epoch 4/24
# ----------
# train Loss: 0.5244 Acc: 0.7941
# val Loss: 0.7601 Acc: 0.7717
# test Loss: 0.6071 Acc: 0.7947
#
# Epoch 5/24
# ----------
# train Loss: 0.4140 Acc: 0.8341
# val Loss: 0.6040 Acc: 0.7874
# test Loss: 0.5880 Acc: 0.7684
#
# Epoch 6/24
# ----------
# train Loss: 0.3202 Acc: 0.8831
# val Loss: 0.6524 Acc: 0.7743
# test Loss: 0.5242 Acc: 0.8316
#
# Epoch 7/24
# ----------
# train Loss: 0.2333 Acc: 0.9208
# val Loss: 0.5131 Acc: 0.8241
# test Loss: 0.4075 Acc: 0.8368
#
# Epoch 8/24
# ----------
# train Loss: 0.2253 Acc: 0.9095
# val Loss: 0.4536 Acc: 0.8373
# test Loss: 0.3291 Acc: 0.8632
#
# Epoch 9/24
# ----------
# train Loss: 0.1789 Acc: 0.9336
# val Loss: 0.4522 Acc: 0.8425
# test Loss: 0.3400 Acc: 0.8474
#
# Epoch 10/24
# ----------
# train Loss: 0.1789 Acc: 0.9374
# val Loss: 0.4134 Acc: 0.8609
# test Loss: 0.3322 Acc: 0.8684
#
# Epoch 11/24
# ----------
# train Loss: 0.1215 Acc: 0.9593
# val Loss: 0.4279 Acc: 0.8530
# test Loss: 0.3589 Acc: 0.8474
#
# Epoch 12/24
# ----------
# train Loss: 0.1342 Acc: 0.9563
# val Loss: 0.4190 Acc: 0.8609
# test Loss: 0.3481 Acc: 0.8579
#
# Epoch 13/24
# ----------
# train Loss: 0.1554 Acc: 0.9502
# val Loss: 0.3977 Acc: 0.8609
# test Loss: 0.3206 Acc: 0.8842
#
# Epoch 14/24
# ----------
# train Loss: 0.1320 Acc: 0.9540
# val Loss: 0.4029 Acc: 0.8504
# test Loss: 0.3205 Acc: 0.8842
#
# Epoch 15/24
# ----------
# train Loss: 0.1237 Acc: 0.9578
# val Loss: 0.4179 Acc: 0.8530
# test Loss: 0.3308 Acc: 0.8947
#
# Epoch 16/24
# ----------
# train Loss: 0.1234 Acc: 0.9540
# val Loss: 0.3860 Acc: 0.8530
# test Loss: 0.3021 Acc: 0.8632
#
# Epoch 17/24
# ----------
# train Loss: 0.1163 Acc: 0.9563
# val Loss: 0.3973 Acc: 0.8504
# test Loss: 0.3171 Acc: 0.8632
#
# Epoch 18/24
# ----------
# train Loss: 0.1370 Acc: 0.9532
# val Loss: 0.3928 Acc: 0.8583
# test Loss: 0.3051 Acc: 0.8789
#
# Epoch 19/24
# ----------
# train Loss: 0.1110 Acc: 0.9630
# val Loss: 0.4167 Acc: 0.8583
# test Loss: 0.3366 Acc: 0.8526
#
# Epoch 20/24
# ----------
# train Loss: 0.1285 Acc: 0.9548
# val Loss: 0.4007 Acc: 0.8609
# test Loss: 0.3221 Acc: 0.8474
#
# Epoch 21/24
# ----------
# train Loss: 0.1257 Acc: 0.9540
# val Loss: 0.4169 Acc: 0.8635
# test Loss: 0.3395 Acc: 0.8474
#
# Epoch 22/24
# ----------
# train Loss: 0.1269 Acc: 0.9623
# val Loss: 0.4206 Acc: 0.8373
# test Loss: 0.3325 Acc: 0.8895
#
# Epoch 23/24
# ----------
# train Loss: 0.0868 Acc: 0.9729
# val Loss: 0.3984 Acc: 0.8530
# test Loss: 0.3209 Acc: 0.8632
#
# Epoch 24/24
# ----------
# train Loss: 0.1113 Acc: 0.9653
# val Loss: 0.4090 Acc: 0.8635
# test Loss: 0.3313 Acc: 0.8474
#
# Training complete in 19m 13s
# Best val Acc: 0.863517
